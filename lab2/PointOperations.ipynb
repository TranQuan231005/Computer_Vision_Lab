# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("input.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 2
#       1 img = cv2.imread("input.jpg")
# ----> 2 img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3
#       4 plt.imshow(img_rgb)
#       5 plt.axis("off")
#
# error: OpenCV(5.0.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\ASUS\Desktop\Computer_Vision_Lab\lab2
# ['.ipynb_checkpoints', 'baitapnangcao.ipynb', 'canny_edge_detection.ipynb', 'images (1).jpg', 'LinearFiltering.ipynb', 'output', 'plan.md', 'README.md', 'Untitled.ipynb', 'visioncanny.py', 'web']

# %%
img = cv2.imread("images (1).jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# %%
bright = cv2.convertScaleAbs(img, alpha=1, beta=50)
dark = cv2.convertScaleAbs(img, alpha=1, beta=-50)

bright_rgb = cv2.cvtColor(bright, cv2.COLOR_BGR2RGB)
dark_rgb = cv2.cvtColor(dark, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img_rgb)
plt.title("Anh goc")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(bright_rgb)
plt.title("Tang sang")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(dark_rgb)
plt.title("Giam sang")
plt.axis("off")

plt.show()

# %%
contrast_low = cv2.convertScaleAbs(img, alpha=0.5, beta=0)
contrast_high = cv2.convertScaleAbs(img, alpha=1.5, beta=0)

contrast_low_rgb = cv2.cvtColor(contrast_low, cv2.COLOR_BGR2RGB)
contrast_high_rgb = cv2.cvtColor(contrast_high, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img_rgb)
plt.title("Anh goc")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(contrast_low_rgb)
plt.title("Tuong phan thap")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(contrast_high_rgb)
plt.title("Tuong phan cao")
plt.axis("off")

plt.show()

# %%
negative = 255 - img

negative_rgb = cv2.cvtColor(negative, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title("Anh goc")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(negative_rgb)
plt.title("Anh am ban")
plt.axis("off")

plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

_, binary = cv2.threshold(
    gray,
    127,
    255,
    cv2.THRESH_BINARY
)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Anh xam")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(binary, cmap="gray")
plt.title("Anh nhi phan")
plt.axis("off")

plt.show()
