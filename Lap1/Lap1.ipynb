# %% [markdown]
# # Lap 1 - Basic Image Processing
#
# This notebook demonstrates basic image processing using OpenCV, Pillow, and Matplotlib.

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

print("Import thư viện thành công!")
# Out:
# Import thư viện thành công!

# %% [markdown]
# ## Phase 1 - Setup
#
# ### Task 1.2 - Import Libraries
#
# Import OpenCV, Pillow, and Matplotlib for image processing.

# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import os

print("OpenCV version:", cv2.__version__)
print("Libraries imported successfully!")
# Out:
# OpenCV version: 5.0.0
# Libraries imported successfully!

# %% [markdown]
# ## Phase 2 - Read and Display Images
#
# ### Task 2.1 - Read an Image
#
# Read `sample.jpg` from the `images/input` directory using OpenCV.

# %%
image_path = "images/input/sample.jpg"

image = cv2.imread(image_path)

if image is None:
    print("Error: Image could not be loaded.")
else:
    print("Image loaded successfully!")
    print("Image shape:", image.shape)
# Out:
# Image loaded successfully!
# Image shape: (739, 415, 3)

# %%
image_path = "images/input/sample.jpg"

image = cv2.imread(image_path)

if image is None:
    print("Error: Image could not be loaded.")
else:
    print("Image loaded successfully!")
    print("Image shape:", image.shape)
# Out:
# Image loaded successfully!
# Image shape: (739, 415, 3)

# %%
image_path = "images/input/sample.jpg"

image = cv2.imread(image_path)

if image is None:
    print("Error: Image could not be loaded.")
else:
    print("Image loaded successfully!")
    print("Image shape:", image.shape)
# Out:
# Image loaded successfully!
# Image shape: (739, 415, 3)

# %%
image_path = "images/input/sample.jpg"

image = cv2.imread(image_path)

if image is None:
    print("Error: Image could not be loaded.")
else:
    print("Image loaded successfully!")
    print("Image shape:", image.shape)
# Out:
# Image loaded successfully!
# Image shape: (739, 415, 3)

# %% [markdown]
# ### Task 2.2 - Display the Image
#
# Display the original image using Matplotlib.
# OpenCV uses BGR color order, so the image is converted to RGB before displaying.

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8, 6))
plt.imshow(image_rgb)
plt.title("Ảnh gốc")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Task 2.3 - Save the Image
#
# Convert the JPG image to PNG format and save it in the output directory using Pillow.

# %%
from shutil import copyfile

os.makedirs("images/output", exist_ok=True)
copyfile(image_path, "images/output/original.jpg")

pil_image = Image.fromarray(image_rgb)

output_path = "images/output/converted_image.png"

pil_image.save(output_path)

print("Image saved successfully!")
print("Output:", output_path)
# Out:
# Image saved successfully!
# Output: images/output/converted_image.png

# %% [markdown]
# ## Phase 3 - Color Space Conversion
#
# ### Task 3.1 - Convert to Grayscale
#
# Convert the original image from BGR color space to grayscale.

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imwrite("images/output/grayscale.jpg", gray)

print("Grayscale conversion completed.")
# Out:
# Grayscale conversion completed.

# %% [markdown]
# ### Task 3.2 - Convert to HSV
#
# Convert the original image from BGR color space to HSV color space.

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

cv2.imwrite("images/output/hsv.jpg", hsv)

print("HSV conversion completed.")
# Out:
# HSV conversion completed.

# %% [markdown]
# ### Task 3.3 - Convert to LAB
#
# Convert the original image from BGR color space to LAB color space.

# %%
lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

cv2.imwrite("images/output/lab.jpg", lab)

print("LAB conversion completed.")
# Out:
# LAB conversion completed.

# %% [markdown]
# ### Task 3.4 - Display Results
#
# Display the grayscale, HSV, and LAB conversion results alongside the original image.

# %%
plt.figure(figsize=(15, 10))

# Grayscale
plt.subplot(2, 2, 1)
plt.imshow(gray, cmap="gray")
plt.title("Grayscale")
plt.axis("off")

# HSV
plt.subplot(2, 2, 2)
plt.imshow(hsv)
plt.title("HSV")
plt.axis("off")

# LAB
plt.subplot(2, 2, 3)
plt.imshow(lab)
plt.title("LAB")
plt.axis("off")

# Original
plt.subplot(2, 2, 4)
plt.imshow(image_rgb)
plt.title("Ảnh gốc")
plt.axis("off")

plt.tight_layout()
plt.show()
